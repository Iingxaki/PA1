# %% [markdown]
# # CS150-01

# %% [markdown]
# ### PA1, Radjamin Hukom, Version 1, Spring 2023

# %% [markdown]
# ## Getting Started With Markdown

# %% [markdown]
# >aaa

# %% [markdown]
# * Course Introduction
# * Variables and Simple Data Types
# * Introducing Lists, Tuples
# * if Statements
# * Dictionaries
# * While Loops
# * Functions
# * Classes
# * Numpy

# %% [markdown]
# 1. Assignment 1
# 2. assignment 2
# 3. assignment 3
# 4. assignment 4
# 5. assignment 5
# 6. assignment 6
# 7. assignment 7

# %% [markdown]
# **I am here**
# *I am here*

# %% [markdown]
# I `am not` here

# %% [markdown]
# `my account` in Github can be found at <a href="https://github.com/Iingxaki/PA1">this link</a>

# %% [markdown]
# ![Dodge Charger](data:image/jpeg;base64,...)
